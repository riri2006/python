# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # Scatter Plot

# %%
x = [56,52,54,60,58]
y=["DL","CC","UDF","ICS","OE"]
plt.scatter(y,x)
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# # Bar Graph

# %%
plt.bar(y,x)
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.show()
